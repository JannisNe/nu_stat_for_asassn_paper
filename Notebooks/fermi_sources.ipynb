# %%
# %matplotlib inline
import matplotlib
from matplotlib.ticker import MultipleLocator
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os, requests, pickle
from astropy.time import Time
from astropy.table import Table
from astropy.coordinates import SkyCoord, Angle
from astropy.io import fits
from astropy import units as u
from style import output_folder, big_fontsize, base_width, base_height, dpi
import seaborn as sns
import json
from alerts import get_alerts
from astropy.time import Time

# %%
alerts = get_alerts()
m = ~alerts.retracted
alert_coords = SkyCoord(alerts[m]['RA'], alerts[m]['Dec'], unit='deg')

cols = ['3FHL Name', '4FGL Name', 'Fermi ra', 'Fermi dec', 'Counterpart', 'Counterpart ra', 'Counterpart dec', 'Counterpart prob']
#fermi_matches = {k: list() for k in cols}
fermi_matches = pd.DataFrame(columns=cols)

for cat, fn in zip(['3FHL', '4FGL'], ["data/gll_psch_v13.fit", "data/gll_psc_v27.fit"]):

    fermi_3fhl = fits.open(fn)
    tab = fermi_3fhl[1]
    fermi_ra = tab.data["RAJ2000"]
    fermi_dec = tab.data["DEJ2000"]
    fermi_coords = SkyCoord(fermi_ra, fermi_dec, unit='deg')

    for j, (i, r) in enumerate(alerts[m].iterrows()):

        #if r.Event != 'IC200911A':
        #    continue

        c = SkyCoord(r['RA'], r['Dec'], unit='deg')
        delta_ra = fermi_coords.ra - c.ra
        delta_dec = fermi_coords.dec - c.dec

        try:    
            if r['Dec Unc (rectangle) float']:
                dec_unc = Angle(r['Dec Unc (rectangle) float']*u.deg)

                if r.Event == "IC190629A":
                    ra_unc = Angle([360, 360]*u.deg)
                else:
                    ra_unc = Angle(r['RA Unc (rectangle) float']*u.deg)

                match_mask = (delta_dec <= max(dec_unc)) & (delta_dec >= min(dec_unc)) & (delta_ra <= max(ra_unc)) & (delta_ra >= min(ra_unc))

            else:
                print(r)
                _sep = Angle(r["initial Error90 [arcmin]"] * u.arcmin)
                sep = c.separation(fermi_coords)
                match_mask = sep <= _sep

        except TypeError as e:
            print(r, "\n", e)

        #test_m = sep**2 == delta_dec**2 + delta_ra**2
        #if not np.all(test_m):
        #    raise Exception(r)

        _matches = tab.data[match_mask]
        
        if cat == '4FGL':
            matches = np.array([
                _matches["ASSOC_FHL"], 
                _matches['Source_Name'], 
                _matches['RAJ2000'], 
                _matches['DEJ2000'],
                _matches['ASSOC1'],
                _matches['RA_Counterpart'],
                _matches['DEC_Counterpart'],
                np.minimum(np.array(_matches['ASSOC_PROB_BAY']).astype(float), np.array(_matches['ASSOC_PROB_LR']).astype(float))
            ]).T
            columns = cols
            
        else:
            matches = np.array([
                _matches['Source_Name'], 
                _matches['RAJ2000'], 
                _matches['DEJ2000'],
                _matches['ASSOC1']
            ]).T
            columns = [f"{cat} Name", "Fermi ra", "Fermi dec", 'Counterpart']
        
        if len(_matches) > 0:
            print(f"{len(_matches)} matches in {cat} for {r.Event}")
            l = np.array([(r.Event, cat, j) for j in range(len(_matches))]).T
            index = pd.MultiIndex.from_arrays(l)
            ifermi_matches = pd.DataFrame(matches, columns=columns, index=index)
            fermi_matches = fermi_matches.append(ifermi_matches)
    
fermi_matches = pd.DataFrame(fermi_matches, 
                             index=pd.MultiIndex.from_tuples(fermi_matches.index,
                                                            names=['Event', 'Fermi Cat', 'Macth ind']))

# %%
with fits.open("data/gll_psc_v27.fit") as h:
    header = h[1].header
    data = h[1].data

# %%
max(data["DataRelease"])
# Out:
# 2

# %%
header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  752 /   length of dimension 1
# NAXIS2  =                 5788 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                   74 /   number of table fields
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# COMMENT
# COMMENT  *** Column names ***
# COMMENT
# TTYPE1  = 'Source_Name'        /
# COMMENT
# COMMENT  *** Column formats ***
# COMMENT
# TFORM1  = '18A     '           /
# TUCD1   = 'meta.id;meta.main'  / UCD for Source_Name
# TTYPE2  = 'DataRelease'        /
# TFORM2  = 'I       '           /
# TNULL2  =                16959 /
# TTYPE3  = 'RAJ2000 '           /
# TFORM3  = 'E       '           /
# TUNIT3  = 'deg     '           /
# TDISP3  = 'F8.4    '           /
# TUCD3   = 'pos.eq.ra;meta.main' / UCD for RAJ2000
# TLMIN3  =             0.000000 / Minimum value for RAJ2000
# TLMAX3  =              360.000 / Maximum value for RAJ2000
# TTYPE4  = 'DEJ2000 '           /
# TFORM4  = 'E       '           /
# TUNIT4  = 'deg     '           /
# TDISP4  = 'F8.4    '           /
# TUCD4   = 'pos.eq.dec;meta.main' / UCD for DEJ2000
# TLMIN4  =             -90.0000 / Minimum value for DEJ2000
# TLMAX4  =              90.0000 / Maximum value for DEJ2000
# TTYPE5  = 'GLON    '           /
# TFORM5  = 'E       '           /
# TUNIT5  = 'deg     '           /
# TDISP5  = 'F8.4    '           /
# TUCD5   = 'pos.galactic.lon'   / UCD for GLON
# TLMIN5  =             0.000000 / Minimum value for GLON
# TLMAX5  =              360.000 / Maximum value for GLON
# TTYPE6  = 'GLAT    '           /
# TFORM6  = 'E       '           /
# TUNIT6  = 'deg     '           /
# TDISP6  = 'F8.4    '           /
# TUCD6   = 'pos.galactic.lat'   / UCD for GLAT
# TLMIN6  =             -90.0000 / Minimum value for GLAT
# TLMAX6  =              90.0000 / Maximum value for GLAT
# TTYPE7  = 'Conf_68_SemiMajor'  /
# TFORM7  = 'E       '           /
# TUNIT7  = 'deg     '           /
# TDISP7  = 'F8.4    '           /
# TUCD7   = 'pos;stat.error'     /
# TLMIN7  =             0.000000 /
# TTYPE8  = 'Conf_68_SemiMinor'  /
# TFORM8  = 'E       '           /
# TUNIT8  = 'deg     '           /
# TDISP8  = 'F8.4    '           /
# TUCD8   = 'pos;stat.error'     /
# TLMIN8  =             0.000000 /
# TTYPE9  = 'Conf_68_PosAng'     /
# TFORM9  = 'E       '           /
# TUNIT9  = 'deg     '           /
# TDISP9  = 'F8.3    '           /
# TUCD9   = 'phys.angSize;stat.error' /
# TTYPE10 = 'Conf_95_SemiMajor'  /
# TFORM10 = 'E       '           /
# TUNIT10 = 'deg     '           /
# TDISP10 = 'F8.4    '           /
# TUCD10  = 'pos;stat.error'     / UCD for Conf_95_SemiMajor
# TLMIN10 =             0.000000 / Minimum value for Conf_95_SemiMajor
# TTYPE11 = 'Conf_95_SemiMinor'  /
# TFORM11 = 'E       '           /
# TUNIT11 = 'deg     '           /
# TDISP11 = 'F8.4    '           /
# TUCD11  = 'pos;stat.error'     / UCD for Conf_95_SemiMinor
# TLMIN11 =             0.000000 / Minimum value for Conf_95_SemiMinor
# TTYPE12 = 'Conf_95_PosAng'     /
# TFORM12 = 'E       '           /
# TUNIT12 = 'deg     '           /
# TDISP12 = 'F8.3    '           /
# TUCD12  = 'phys.angSize;stat.error' / UCD for Conf_95_PosAng
# TTYPE13 = 'ROI_num '           /
# TFORM13 = 'I       '           /
# TNULL13 =                16959 /
# TTYPE14 = 'Extended_Source_Name' /
# TFORM14 = '18A     '           /
# TTYPE15 = 'Signif_Avg'         /
# TFORM15 = 'E       '           /
# TDISP15 = 'F8.3    '           /
# TUCD15  = 'stat.snr'           / UCD for Signif_Avg
# TLMIN15 =             0.000000 / Minimum value for Signif_Avg
# TTYPE16 = 'Pivot_Energy'       /
# TFORM16 = 'E       '           /
# TUNIT16 = 'MeV     '           /
# TDISP16 = 'F10.2   '           /
# TUCD16  = 'em.energy'          / UCD for Pivot_Energy
# TLMIN16 =             0.000000 / Minimum value for Pivot_Energy
# TTYPE17 = 'Flux1000'           /
# TFORM17 = 'E       '           /
# TUNIT17 = 'ph cm-2 s-1'        /
# TDISP17 = 'E10.4   '           /
# TUCD17  = 'phot.count;em.gamma' / UCD for Flux1000
# TLMIN17 =             0.000000 / Minimum value for Flux1000
# TEMIN17 =              1000.00 / [MeV] Minimum refenergy for Flux1000
# TEMAX17 =        100000.000000 / [MeV] Maximum refenergy for Flux1000
# TTYPE18 = 'Unc_Flux1000'       /
# TFORM18 = 'E       '           /
# TUNIT18 = 'ph cm-2 s-1'        /
# TDISP18 = 'E10.4   '           /
# TUCD18  = 'phot.count;em.gamma;stat.error' / UCD for Unc_Flux1000
# TEMIN18 =              1000.00 / [MeV] Minimum refenergy for Unc_Flux1000
# TEMAX18 =        100000.000000 / [MeV] Maximum refenergy for Unc_Flux1000
# TTYPE19 = 'Energy_Flux100'     /
# TFORM19 = 'E       '           /
# TUNIT19 = 'erg cm-2 s-1'       /
# TDISP19 = 'E10.4   '           /
# TUCD19  = 'phot.flux;em.gamma' / UCD for Energy_Flux100
# TLMIN19 =             0.000000 / Minimum value for Energy_Flux100
# TEMIN19 =                  100 / [MeV] Minimum refenergy for Energy_Flux100
# TEMAX19 =        100000.000000 / [MeV] Maximum refenergy for Energy_Flux100
# TTYPE20 = 'Unc_Energy_Flux100' /
# TFORM20 = 'E       '           /
# TUNIT20 = 'erg cm-2 s-1'       /
# TDISP20 = 'E10.4   '           /
# TUCD20  = 'phot.flux;em.gamma;stat.error' / UCD for Unc_Energy_Flux100
# TLMIN20 =             0.000000 / Minimum value for Unc_Energy_Flux100
# TEMIN20 =                  100 / [MeV] Minimum refenergy for Unc_Energy_Flux100
# TEMAX20 =        100000.000000 / [MeV] Maximum refenergy for Unc_Energy_Flux100
# TTYPE21 = 'SpectrumType'       /
# TFORM21 = '17A     '           /
# TTYPE22 = 'PL_Flux_Density'    /
# TFORM22 = 'E       '           /
# TUNIT22 = 'ph cm-2 MeV-1 s-1'  /
# TDISP22 = 'E10.4   '           /
# TUCD22  = 'phot.flux.density'  / UCD for PL_Flux_Density
# TLMIN22 =             0.000000 / Minimum value for PL_Flux_Density
# TTYPE23 = 'Unc_PL_Flux_Density' /
# TFORM23 = 'E       '           /
# TUNIT23 = 'ph cm-2 MeV-1 s-1'  /
# TDISP23 = 'E10.4   '           /
# TUCD23  = 'phot.flux.density;stat.error' / UCD for Unc_PL_Flux_Density
# TLMIN23 =             0.000000 / Minimum value for Unc_PL_Flux_Density
# TTYPE24 = 'PL_Index'           /
# TFORM24 = 'E       '           /
# TDISP24 = 'F8.4    '           /
# TUCD24  = 'spect.index'        / UCD for PL_Index
# TLMIN24 =             0.000000 / Minimum value for PL_Index
# TLMAX24 =              5.00000 / Maximum value for PL_Index
# TTYPE25 = 'Unc_PL_Index'       /
# TFORM25 = 'E       '           /
# TDISP25 = 'F8.4    '           /
# TUCD25  = 'spect.index;stat.error' / UCD for Unc_PL_Index
# TLMIN25 =             0.000000 / Minimum value for Unc_PL_Index
# TLMAX25 =              5.00000 / Maximum value for Unc_PL_Index
# TTYPE26 = 'LP_Flux_Density'    /
# TFORM26 = 'E       '           /
# TUNIT26 = 'ph cm-2 MeV-1 s-1'  /
# TDISP26 = 'E10.4   '           /
# TUCD26  = 'phot.flux.density'  / UCD for LP_Flux_Density
# TLMIN26 =             0.000000 / Minimum value for LP_Flux_Density
# TTYPE27 = 'Unc_LP_Flux_Density' /
# TFORM27 = 'E       '           /
# TUNIT27 = 'ph cm-2 MeV-1 s-1'  /
# TDISP27 = 'E10.4   '           /
# TUCD27  = 'phot.flux.density;stat.error' / UCD for Unc_LP_Flux_Density
# TLMIN27 =             0.000000 / Minimum value for Unc_LP_Flux_Density
# TTYPE28 = 'LP_Index'           /
# TFORM28 = 'E       '           /
# TDISP28 = 'F8.4    '           /
# TUCD28  = 'spect.index'        / UCD for LP_Index
# TLMIN28 =             0.000000 / Minimum value for LP_Index
# TLMAX28 =              5.00000 / Maximum value for LP_Index
# TTYPE29 = 'Unc_LP_Index'       /
# TFORM29 = 'E       '           /
# TDISP29 = 'F8.4    '           /
# TUCD29  = 'spect.index;stat.error' / UCD for Unc_LP_Index
# TLMIN29 =             0.000000 / Minimum value for Unc_LP_Index
# TLMAX29 =              5.00000 / Maximum value for Unc_LP_Index
# TTYPE30 = 'LP_beta '           /
# TFORM30 = 'E       '           /
# TDISP30 = 'F8.4    '           /
# TLMIN30 =             -1.00000 / Minimum value for LP_beta
# TLMAX30 =              1.00000 / Maximum value for LP_beta
# TTYPE31 = 'Unc_LP_beta'        /
# TFORM31 = 'E       '           /
# TDISP31 = 'F8.4    '           /
# TTYPE32 = 'LP_SigCurv'         /
# TFORM32 = 'E       '           /
# TDISP32 = 'F8.3    '           /
# TUCD32  = 'stat.snr'           /
# TLMIN32 =             0.000000 /
# TTYPE33 = 'PLEC_Flux_Density'  /
# TFORM33 = 'E       '           /
# TUNIT33 = 'ph cm-2 MeV-1 s-1'  /
# TDISP33 = 'E10.4   '           /
# TUCD33  = 'phot.flux.density'  / UCD for PLEC_Flux_Density
# TLMIN33 =             0.000000 / Minimum value for PLEC_Flux_Density
# TTYPE34 = 'Unc_PLEC_Flux_Density' /
# TFORM34 = 'E       '           /
# TUNIT34 = 'ph cm-2 MeV-1 s-1'  /
# TDISP34 = 'E10.4   '           /
# TUCD34  = 'phot.flux.density;stat.error' / UCD for Unc_PLEC_Flux_Density
# TLMIN34 =             0.000000 / Minimum value for Unc_PLEC_Flux_Density
# TTYPE35 = 'PLEC_Index'         /
# TFORM35 = 'E       '           /
# TDISP35 = 'F8.4    '           /
# TUCD35  = 'spect.index'        / UCD for PLEC_Index
# TLMIN35 =             0.000000 / Minimum value for PLEC_Index
# TLMAX35 =              5.00000 / Maximum value for PLEC_Index
# TTYPE36 = 'Unc_PLEC_Index'     /
# TFORM36 = 'E       '           /
# TDISP36 = 'F8.4    '           /
# TUCD36  = 'spect.index;stat.error' / UCD for Unc_PLEC_Index
# TLMIN36 =             0.000000 / Minimum value for Unc_PLEC_Index
# TLMAX36 =              5.00000 / Maximum value for Unc_PLEC_Index
# TTYPE37 = 'PLEC_Expfactor'     /
# TFORM37 = 'E       '           /
# TDISP37 = 'F8.5    '           /
# TLMIN37 =           -0.0100000 / Minimum value for PLEC_Expfactor
# TLMAX37 =              1.00000 / Maximum value for PLEC_Expfactor
# TTYPE38 = 'Unc_PLEC_Expfactor' /
# TFORM38 = 'E       '           /
# TDISP38 = 'F8.5    '           /
# TTYPE39 = 'PLEC_Exp_Index'     /
# TFORM39 = 'E       '           /
# TDISP39 = 'F8.4    '           /
# TLMIN39 =             0.000000 / Minimum value for PLEC_Exp_Index
# TLMAX39 =              5.00000 / Maximum value for PLEC_Exp_Index
# TTYPE40 = 'Unc_PLEC_Exp_Index' /
# TFORM40 = 'E       '           /
# TDISP40 = 'F8.4    '           /
# TLMIN40 =             0.000000 / Minimum value for Unc_PLEC_Exp_Index
# TLMAX40 =              5.00000 / Maximum value for Unc_PLEC_Exp_Index
# TTYPE41 = 'PLEC_SigCurv'       /
# TFORM41 = 'E       '           /
# TDISP41 = 'F8.3    '           /
# TUCD41  = 'stat.snr'           /
# TLMIN41 =             0.000000 /
# TTYPE42 = 'Npred   '           /
# TFORM42 = 'E       '           /
# TDISP42 = 'F10.2   '           /
# TLMIN42 =             0.000000 / Minimum value for Npred
# TTYPE43 = 'Flux_Band'          /
# TFORM43 = '7E      '           /
# TUNIT43 = 'ph cm-2 s-1'        /
# TUCD43  = 'phot.count;em.gamma' / UCD for Flux_Band
# TTYPE44 = 'Unc_Flux_Band'      /
# TFORM44 = '14E     '           /
# TUNIT44 = 'ph cm-2 s-1'        /
# TDIM44  = '( 2, 7) '           /
# TUCD44  = 'phot.count;em.gamma;stat.error' / UCD for Unc_Flux_Band
# TTYPE45 = 'nuFnu_Band'         /
# TFORM45 = '7E      '           /
# TUNIT45 = 'erg cm-2 s-1'       /
# TUCD45  = 'phot.flux.density;em.gamma' / UCD for nuFnu_Band
# TTYPE46 = 'Sqrt_TS_Band'       /
# TFORM46 = '7E      '           /
# TUCD46  = 'stat.snr'           / UCD for Sqrt_TS_Band
# TTYPE47 = 'Variability_Index'  /
# TFORM47 = 'E       '           /
# TDISP47 = 'F10.4   '           /
# TUCD47  = 'src.var.index;stat.chi2' / UCD for Variability_Index
# TTYPE48 = 'Frac_Variability'   /
# TFORM48 = 'E       '           /
# TDISP48 = 'F7.4    '           /
# TUCD48  = 'src.var.amplitude'  / UCD for Frac_Variability
# TTYPE49 = 'Unc_Frac_Variability' /
# TFORM49 = 'E       '           /
# TDISP49 = 'F7.4    '           /
# TUCD49  = 'src.var.amplitude;stat.error' / UCD for Unc_Frac_Variability
# TTYPE50 = 'Signif_Peak'        /
# TFORM50 = 'E       '           /
# TDISP50 = 'F8.3    '           /
# TUCD50  = 'stat.snr'           / UCD for Signif_Peak
# TTYPE51 = 'Flux_Peak'          /
# TFORM51 = 'E       '           /
# TUNIT51 = 'ph cm-2 s-1'        /
# TUCD51  = 'phot.count;em.gamma' / UCD for Flux_Peak
# TEMIN51 =              50.0000 / Minimum energy for Flux_Peak(MeV)
# TEMAX51 =        100000.000000 / Maximum energy for Flux_Peak(MeV)
# TTYPE52 = 'Unc_Flux_Peak'      /
# TFORM52 = 'E       '           /
# TUNIT52 = 'ph cm-2 s-1'        /
# TUCD52  = 'phot.count;em.gamma;stat.error' / UCD for Unc_Flux_Peak
# TEMIN52 =              50.0000 / Minimum energy for Unc_Flux_Peak(MeV)
# TEMAX52 =        100000.000000 / Maximum energy for Unc_Flux_Peak(MeV)
# TTYPE53 = 'Time_Peak'          /
# TFORM53 = 'D       '           /
# TUNIT53 = 's       '           /
# TUCD53  = 'time.epoch'         / UCD for Time_Peak
# TTYPE54 = 'Peak_Interval'      /
# TFORM54 = 'E       '           /
# TUNIT54 = 's       '           /
# TUCD54  = 'time.interval'      / UCD for Peak_Interval
# TTYPE55 = 'Flux_History'       /
# TFORM55 = '10E     '           /
# TUNIT55 = 'ph cm-2 s-1'        /
# TUCD55  = 'phot.count;em.gamma' / UCD for Flux_History
# TEMIN55 =              50.0000 / Minimum energy for Flux_History(MeV)
# TEMAX55 =        100000.000000 / Maximum energy for Flux_History(MeV)
# TTYPE56 = 'Unc_Flux_History'   /
# TFORM56 = '20E     '           /
# TUNIT56 = 'ph cm-2 s-1'        /
# TDIM56  = '( 2, 10)'           /
# TUCD56  = 'phot.count;em.gamma;stat.error' / UCD for Unc_Flux_History
# TEMIN56 =              50.0000 / Minimum energy for Unc_Flux_History(MeV)
# TEMAX56 =        100000.000000 / Maximum energy for Unc_Flux_History(MeV)
# TTYPE57 = 'Sqrt_TS_History'    /
# TFORM57 = '10E     '           /
# TUCD57  = 'stat.snr'           / UCD for Sqrt_TS_History
# TTYPE63 = 'TEVCAT_FLAG'        /
# TFORM63 = 'A       '           /
# TTYPE64 = 'ASSOC_TEV'          /
# TFORM64 = '26A     '           /
# TTYPE65 = 'CLASS1  '           /
# TFORM65 = '5A      '           /
# TTYPE67 = 'ASSOC1  '           /
# TFORM67 = '28A     '           /
# TTYPE69 = 'ASSOC_PROB_BAY'     /
# TFORM69 = 'E       '           /
# TTYPE70 = 'ASSOC_PROB_LR'      /
# TFORM70 = 'E       '           /
# TTYPE71 = 'RA_Counterpart'     /
# TFORM71 = 'D       '           /
# TUNIT71 = 'deg     '           /
# TTYPE72 = 'DEC_Counterpart'    /
# TFORM72 = 'D       '           /
# TUNIT72 = 'deg     '           /
# TTYPE73 = 'Unc_Counterpart'    /
# TFORM73 = 'E       '           /
# TUNIT73 = 'deg     '           /
# TTYPE74 = 'Flags   '           /
# TFORM74 = 'I       '           /
# COMMENT
# COMMENT  *** Column dimensions (2 D or greater) ***
# COMMENT
# TELESCOP= 'GLAST   '           / name of telescope generating data
# INSTRUME= 'LAT     '           / name of instrument generating data
# EQUINOX =               2000.0 / equinox for ra and dec
# RADECSYS= 'FK5     '           / world coord. system for this file (FK5 or FK4)
# DATE    = '2020-10-29T18:49:42' / file creation date (UTC)
# DATE-OBS= '2008-08-04T15:43:36.4941' / start date/time of the obs. (UTC)
# DATE-END= '2018-08-02T19:13:14.9999' / end date/time of the obs. (UTC)
# TSTART  =     239557417.494176 / mission time of the obs. start
# TSTOP   =          554930000.0 / mission time of the obs. end
# TIMEUNIT= 's       '           / units for the time related keywords
# TIMESYS = 'TT      '           / type of time system that is used
# MJDREFI =              51910.0 / Integer part of MJD corresponding to SC clock s
# MJDREFF = '7.428703703703703D-4' /Frac. part of MJD of SC clock start
# OBSERVER= 'Peter Michelson'    / GLAST/LAT PI
# FILENAME= 'gll_pscP305uw9011iG5_v17.fit' / name of this file
# ORIGIN  = 'LISOC   '           / name of organization making file
# CREATOR = 'PointSourceCat'     / software and version creating file
# VERSION = 'v27     '           / release version of the file
# EXTNAME = 'LAT_Point_Source_Catalog' / name of this binary table extension
# HDUDOC  = 'GLAST Project Science Data products format document' / Document descr
# HDUCLASS= 'OGIP    '           / format conforms to OGIP standard
# HDUVERS = '1.0.0   '           / version of the format
# HDUCLAS1= 'SRCLIST '           / an OGIP standard class
# CDS-NAME= '4FGL    '           / Catalog Name
# STVERS  = '/dsm/saplxglast/glast/anaconda2/envs/fermi-1.3.5/share/fermitools'
# PIPVERS = 'Gpipeline-v7r13p5'  / Pipeline code version
# RUNNAME = 'P8R3_uw9011'        / Name of Run
# RSPFUNC = 'P8R3_SOURCE_V3'     / Response function
# TSMIN   =                   25 / Test Statistic Treshold
# NPREDMIN=                 10.0 / Minimum number of source events
# EMIN    =                   50 / [MeV] low limit for the energy band
# EMAX    =            1000000.0 / [MeV] high limit for the energy band
# ENERDISP= 'yes     '           / Account for energy dispersion ?
# SYSREL  =                  0.0 / Relative systematic error for flux
# ERRUPLIM=                  2.0 / Minimum Relative error for Upperlimits
# TSUPLIM =                  1.0 / Maximum TS for Upperlimits
# ERPOSABS= '0.0068  '           / systematic value (deg) added in quadrature conf
# ERPOSFAC= '1.060   '           / Systematic factor applied to conf95
# TSCURMIN=                    9 / TSCurv threshold for moving to curved spectrum
# CHECKSUM= 'KNdANLd5KLdAKLd3'   / HDU checksum updated 2020-12-16T13:31:31
# DATASUM = '3260316208'         / data unit checksum updated 2020-12-16T13:31:31
# ERFLUVAR=                  0.0 / Relative systematic error for flux variability
# VARMODE = 'loglike '           / Variability computation mode 'chi2'|'loglike'
# VARMIN  =        21.6659943345 / Variability index threshold
# DATE-HDU= '2020-02-21T10:44:49'
# STILVERS= '3.3-3   '
# STILCLAS= 'uk.ac.starlink.votable.FitsPlusTableWriter'
# HISTORY File modified by user 'local1' with fv  on 2020-03-12T12:10:18
# TDISP69 = 'F6.4    '           /
# TDISP70 = 'F6.4    '           /
# TDISP71 = 'F8.4    '           /
# TDISP72 = 'F8.4    '           /
# TDISP73 = 'F8.5    '           /
# TUCD58  = 'meta.id.assoc'      /
# TUCD59  = 'meta.id.assoc'      /
# TUCD60  = 'meta.id.assoc'      /
# TUCD61  = 'meta.id.assoc'      /
# TUCD62  = 'meta.id.assoc'      /
# TUCD63  = 'meta.code'          /
# TUCD64  = 'meta.id.assoc'      /
# TUCD65  = 'src.class'          /
# TUCD66  = 'src.class'          /
# TUCD67  = 'meta.id.assoc'      /
# TUCD68  = 'meta.id.assoc'      /
# TUCD69  = 'stat.probability'   /
# TUCD70  = 'stat.probability'   /
# TUCD71  = 'pos.eq.ra'          /
# TUCD72  = 'pos.eq.dec'         /
# TUCD73  = 'pos;stat.error'     /
# TUCD74  = 'meta.code.qual'     /
# TLMIN2  =                    1 /
# TLMAX2  =                    2 /
# TLMIN69 =             0.000000 /
# TLMIN70 =             0.000000 /
# TLMAX69 =              1.00000 /
# TLMAX70 =              1.00000 /
# TLMIN71 =             0.000000 /
# TLMAX71 =              360.000 /
# TLMIN72 =             -90.0000 /
# TLMAX72 =              90.0000 /
# TLMIN73 =             0.000000 /
# TFORM58 = '18A     '           /
# TFORM59 = '18A     '           /
# TFORM60 = '18A     '           /
# TFORM61 = '18A     '           /
# TFORM62 = '18A     '           /
# TFORM66 = '5A      '           /
# TFORM68 = '26A     '           /
# TTYPE58 = 'ASSOC_FGL'          /
# TTYPE59 = 'ASSOC_FHL'          /
# TTYPE60 = 'ASSOC_GAM1'         /
# TTYPE61 = 'ASSOC_GAM2'         /
# TTYPE62 = 'ASSOC_GAM3'         /
# TTYPE66 = 'CLASS2  '           /
# TTYPE68 = 'ASSOC2  '           /

# %% [markdown]
# ### Math the 3FHL and the 4FGL Catalogues and remove the duplicat entries ###

# %%
drop_m = fermi_matches['3FHL Name'].duplicated(keep=False) & fermi_matches['4FGL Name'].isna()
print(f"found {len(fermi_matches[drop_m])} duplicates")
fermi_matches = fermi_matches[~drop_m]
print(len(fermi_matches))
print(len(fermi_matches[fermi_matches["4FGL Name"].isna() & (~fermi_matches["3FHL Name"].isna())]))

for x in ['ra', 'dec']:
    counterpart = fermi_matches[f"Counterpart {x}"]
    fermi = fermi_matches[f"Fermi {x}"]
    xm = (~counterpart.isna()) & (np.array(fermi_matches['Counterpart prob']).astype(float) > 0)
    fermi_matches[x] = fermi
    fermi_matches.loc[xm, x] = counterpart[xm]
    
has_cp = ~np.isnan(np.array(fermi_matches['Counterpart dec']).astype(float))

for k in ['Counterpart', 'Counterpart ra', 'Counterpart dec']:
    fermi_matches.loc[~has_cp, k] = ""

ncp = len(fermi_matches[has_cp])
print(f"{ncp} with counterpart, {len(fermi_matches) - ncp} without")
fermi_matches.to_csv('data/fermi_matches.csv')    
fermi_matches
# Out:
# found 55 duplicates
# 177
# 0
# 139 with counterpart, 38 without
#                                         3FHL Name           4FGL Name  \
# Event     Fermi Cat Macth ind
# IC161103A 4FGL      0                              4FGL J0244.7+1316
# IC170922A 4FGL      0          3FHL J0509.4+0542   4FGL J0509.4+0542
# IC181014A 4FGL      0          3FHL J1457.5-3538   4FGL J1457.4-3539
#                     1                              4FGL J1505.0-3433
# IC181023A 4FGL      0                              4FGL J1804.4-0852
# ...                                           ...                 ...
# IC210608A 4FGL      14                             4FGL J2248.9+2106
# IC210717A 4FGL      0                              4FGL J0256.2-0408
#                     1          3FHL J0304.5-0055   4FGL J0304.5-0054
#                     2                              4FGL J0307.8-0419
# IC210730A 4FGL      0                              4FGL J0659.7+1416
#
#                                Fermi ra Fermi dec  \
# Event     Fermi Cat Macth ind
# IC161103A 4FGL      0            41.192   13.2799
# IC170922A 4FGL      0           77.3593    5.7014
# IC181014A 4FGL      0          224.3657  -35.6527
#                     1          226.2581  -34.5546
# IC181023A 4FGL      0          271.1182   -8.8694
# ...                                 ...       ...
# IC210608A 4FGL      14         342.2461   21.1159
# IC210717A 4FGL      0           44.0544    -4.134
#                     1           46.1423   -0.9148
#                     2           46.9523   -4.3266
# IC210730A 4FGL      0          104.9416   14.2792
#
#                                                 Counterpart  \
# Event     Fermi Cat Macth ind
# IC161103A 4FGL      0          GB6 J0244+1320
# IC170922A 4FGL      0          TXS 0506+056
# IC181014A 4FGL      0          PKS 1454-354
#                     1          PMN J1505-3432
# IC181023A 4FGL      0
# ...                                                     ...
# IC210608A 4FGL      14         PKS 2246+208
# IC210717A 4FGL      0
#                     1          RX J0304.5-0054
#                     2          LEDA 095522
# IC210730A 4FGL      0          PSR J0659+1414
#
#                                   Counterpart ra     Counterpart dec  \
# Event     Fermi Cat Macth ind
# IC161103A 4FGL      0              41.1903889042          13.3353393
# IC170922A 4FGL      0              77.3581852833       5.69314818611
# IC181014A 4FGL      0               224.36129875      -35.6527698861
#                     1              226.259876379      -34.5491167778
# IC181023A 4FGL      0
# ...                                          ...                 ...
# IC210608A 4FGL      14             342.252361346          21.1174543
# IC210717A 4FGL      0
#                     1              46.1414966667         -0.90130895
#                     2              46.9354854083      -4.31923459167
# IC210730A 4FGL      0          104.9505615234375  14.239310264587402
#
#                                  Counterpart prob                 ra  \
# Event     Fermi Cat Macth ind
# IC161103A 4FGL      0                         0.0             41.192
# IC170922A 4FGL      0          0.9901848435401917      77.3581852833
# IC181014A 4FGL      0           0.994556725025177       224.36129875
#                     1          0.9717896580696106      226.259876379
# IC181023A 4FGL      0                         0.0           271.1182
# ...                                           ...                ...
# IC210608A 4FGL      14         0.9745596051216125      342.252361346
# IC210717A 4FGL      0                         0.0            44.0544
#                     1          0.9383262395858765      46.1414966667
#                     2          0.8354509472846985      46.9354854083
# IC210730A 4FGL      0          0.9872325658798218  104.9505615234375
#
#                                               dec
# Event     Fermi Cat Macth ind
# IC161103A 4FGL      0                     13.2799
# IC170922A 4FGL      0               5.69314818611
# IC181014A 4FGL      0              -35.6527698861
#                     1              -34.5491167778
# IC181023A 4FGL      0                     -8.8694
# ...                                           ...
# IC210608A 4FGL      14                 21.1174543
# IC210717A 4FGL      0                      -4.134
#                     1                 -0.90130895
#                     2              -4.31923459167
# IC210730A 4FGL      0          14.239310264587402
#
# [177 rows x 10 columns]

# %%
cmap = plt.get_cmap()

for i, r in alerts.iterrows():
    
    try:
        sources = fermi_matches.loc[pd.IndexSlice[r.Event, :, :]]
    except KeyError:
        continue
    
    sources = sources[~sources['4FGL Name'].isna()]
    
    if len(sources) > 0:
        print(sources.to_string(index=False))

        fig, ax = plt.subplots(figsize=(base_width, base_height), dpi=dpi)

        ax.set_aspect(1, adjustable='datalim')
        ax.scatter(r['RA'], r['Dec'], color=cmap(0), marker='s', s=2)
        if r['RA Unc (rectangle) float'] and r['Dec Unc (rectangle) float']:
            left_bottom_corner = (r['RA'] + r['RA Unc (rectangle) float'][1], r['Dec'] + r['Dec Unc (rectangle) float'][1])
            extent = (r['RA Unc (rectangle) float'][0] - r['RA Unc (rectangle) float'][1],
                      r['Dec Unc (rectangle) float'][0] - r['Dec Unc (rectangle) float'][1])
            final_e = plt.Rectangle(left_bottom_corner, extent[0], extent[1], fc=cmap(0), alpha=0.4, ec=None, ls='')
            ax.add_patch(final_e)
        else:
            print(r)

        ax.scatter(r['initial RA'], r['initial Dec'], color=cmap(0.2), s=2)
        initial_e = r['initial Error90 [arcmin]'] * u.arcmin
        initial_contour = plt.Circle((r['initial RA'], r['initial Dec']), initial_e.to('deg').value, alpha=0.4, fc=cmap(0.2), ec=None, ls='')
        ax.add_patch(initial_contour)

        ax.scatter(np.array(sources['ra']).astype(float), 
                   np.array(sources['dec']).astype(float), marker='x', color=cmap(0.8))
        fgl = ~sources['4FGL Name'].isna()
        for _, s in sources[fgl].iterrows():
            ylim = ax.get_ylim()
            yext = abs(ylim[1] - ylim[0])
            n = s['Counterpart'] if s['Counterpart'] else s['4FGL Name']
            ax.annotate(n, (float(s.ra), float(s.dec) + yext/12), ha='center', color=cmap(0.8), fontsize=6,
                       snap=True)

        ax.set_title(r.Event)
        major_base = 20 if r.Event=="IC190331A" in cc else 1
        ax.xaxis.set_major_locator(MultipleLocator(base=major_base))
        ax.yaxis.set_major_locator(MultipleLocator(base=major_base))
        ax.grid()

        ax.set_xlabel('RA')
        ax.set_ylabel('Dec')


        fig.tight_layout()
        fig.savefig(os.path.join(output_folder, f"{r.Event}.pdf"))
        try:
            plt.show()
        finally:
            plt.close()

# %%
pd.read_csv("data/fermi_matches.csv", index_col=[0,1,2])
# Out:
#                                         3FHL Name           4FGL Name  \
# Event     Fermi Cat Macth ind
# IC161103A 4FGL      0                              4FGL J0244.7+1316
# IC170922A 4FGL      0          3FHL J0509.4+0542   4FGL J0509.4+0542
# IC181014A 4FGL      0          3FHL J1457.5-3538   4FGL J1457.4-3539
#                     1                              4FGL J1505.0-3433
# IC181023A 4FGL      0                              4FGL J1804.4-0852
# ...                                           ...                 ...
# IC210608A 4FGL      14                             4FGL J2248.9+2106
# IC210717A 4FGL      0                              4FGL J0256.2-0408
#                     1          3FHL J0304.5-0055   4FGL J0304.5-0054
#                     2                              4FGL J0307.8-0419
# IC210730A 4FGL      0                              4FGL J0659.7+1416
#
#                                Fermi ra  Fermi dec  \
# Event     Fermi Cat Macth ind
# IC161103A 4FGL      0           41.1920    13.2799
# IC170922A 4FGL      0           77.3593     5.7014
# IC181014A 4FGL      0          224.3657   -35.6527
#                     1          226.2581   -34.5546
# IC181023A 4FGL      0          271.1182    -8.8694
# ...                                 ...        ...
# IC210608A 4FGL      14         342.2461    21.1159
# IC210717A 4FGL      0           44.0544    -4.1340
#                     1           46.1423    -0.9148
#                     2           46.9523    -4.3266
# IC210730A 4FGL      0          104.9416    14.2792
#
#                                                 Counterpart  Counterpart ra  \
# Event     Fermi Cat Macth ind
# IC161103A 4FGL      0          GB6 J0244+1320                     41.190389
# IC170922A 4FGL      0          TXS 0506+056                       77.358185
# IC181014A 4FGL      0          PKS 1454-354                      224.361299
#                     1          PMN J1505-3432                    226.259876
# IC181023A 4FGL      0                                   NaN             NaN
# ...                                                     ...             ...
# IC210608A 4FGL      14         PKS 2246+208                      342.252361
# IC210717A 4FGL      0                                   NaN             NaN
#                     1          RX J0304.5-0054                    46.141497
#                     2          LEDA 095522                        46.935485
# IC210730A 4FGL      0          PSR J0659+1414                    104.950562
#
#                                Counterpart dec  Counterpart prob          ra  \
# Event     Fermi Cat Macth ind
# IC161103A 4FGL      0                13.335339          0.000000   41.192000
# IC170922A 4FGL      0                 5.693148          0.990185   77.358185
# IC181014A 4FGL      0               -35.652770          0.994557  224.361299
#                     1               -34.549117          0.971790  226.259876
# IC181023A 4FGL      0                      NaN          0.000000  271.118200
# ...                                        ...               ...         ...
# IC210608A 4FGL      14               21.117454          0.974560  342.252361
# IC210717A 4FGL      0                      NaN          0.000000   44.054400
#                     1                -0.901309          0.938326   46.141497
#                     2                -4.319235          0.835451   46.935485
# IC210730A 4FGL      0                14.239310          0.987233  104.950562
#
#                                      dec
# Event     Fermi Cat Macth ind
# IC161103A 4FGL      0          13.279900
# IC170922A 4FGL      0           5.693148
# IC181014A 4FGL      0         -35.652770
#                     1         -34.549117
# IC181023A 4FGL      0          -8.869400
# ...                                  ...
# IC210608A 4FGL      14         21.117454
# IC210717A 4FGL      0          -4.134000
#                     1          -0.901309
#                     2          -4.319235
# IC210730A 4FGL      0          14.239310
#
# [177 rows x 10 columns]
